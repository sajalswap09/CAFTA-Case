# %%
import pandas

# %%
import pandas as pd

# %%
cd "C:\Users\sajal\Downloads"
# Out:
# C:\Users\sajal\Downloads

# %%
df=pd.read_excel('MulReg.xlsx')

# %%
#df

# %%
df.fillna(method='ffill', inplace=True)
df
# Out:
#        Symbol       Date  Year  month     Key      VALUE     AdjVal  \
# 0     USD/INR 2015-01-01  2015      1   20151  63.028000  52.690000
# 1     USD/INR 2015-01-02  2015      1   20151  63.028000  52.689999
# 2     USD/INR 2015-01-05  2015      1   20151  63.278000  50.040001
# 3     USD/INR 2015-01-06  2015      1   20151  63.338001  47.930000
# 4     USD/INR 2015-01-07  2015      1   20151  63.568001  48.650002
# 5     USD/INR 2015-01-08  2015      1   20151  63.272999  48.790001
# 6     USD/INR 2015-01-09  2015      1   20151  62.667999  48.360001
# 7     USD/INR 2015-01-12  2015      1   20151  62.348000  46.070000
# 8     USD/INR 2015-01-13  2015      1   20151  62.068001  45.889999
# 9     USD/INR 2015-01-14  2015      1   20151  61.973000  48.480000
# 10    USD/INR 2015-01-15  2015      1   20151  62.088001  46.250000
# 11    USD/INR 2015-01-16  2015      1   20151  62.057999  48.689999
# 12    USD/INR 2015-01-19  2015      1   20151  61.862999  48.689999
# ...

# %%
X=df[['AdjVal','Lending','Purchase','Gold','Inflation']]
Y=df['VALUE']

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
regr = linear_model.LinearRegression()
#regr.fit(X, Y)

# %%
x_train, x_test, y_train, y_test=train_test_split(X,Y,test_size=0.40,random_state=42)

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(regr.coef_)
# Out:
# [-1.97256248e-02 -1.31792014e+00  2.89184621e-05  5.11996440e-03
#   4.10089769e-02]

# %%
y_pred=regr.predict(x_test)
#print(y_pred)

# %%
#print(y_test)

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
# Out:
# 9.18691345972866

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred,color="blue")
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2,color="red")
ax.set_title('Predicted vs Measured Curr Value')
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
